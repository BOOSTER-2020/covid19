# %%
#Importing Libraries !!
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split  
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, classification_report
from sklearn import tree
from sklearn.tree import export_graphviz
import matplotlib.pyplot as plt  
# %matplotlib inline
from sklearn import metrics
import seaborn as sn
import warnings
warnings.filterwarnings('ignore')

# %%
from fbprophet import Prophet

# %%
data=pd.read_csv("state_wise_daily.csv")

# %%
confirm_data=data[data["Status"]=="Confirmed"]

# %%
confirm_data=confirm_data[confirm_data["Date"]>="2020-06-01"]

# %%
confirm_data.reset_index(inplace=True)

# %%
confirm_data.head()
# Out:
#    index       Date     Status   TT  AN  AP  AR  AS  BR  CH ...  PB  RJ  SK  \
# 0     21  21-Mar-20  Confirmed   78   0   2   0   0   0   0 ...  10   7   0
# 1     24  22-Mar-20  Confirmed   67   0   1   0   0   2   1 ...   8   4   0
# 2     27  23-Mar-20  Confirmed  102   0   1   0   0   1   1 ...   2   4   0
# 3     30  24-Mar-20  Confirmed   64   0   1   0   0   0   0 ...   6   0   0
# 4     33  25-Mar-20  Confirmed   90   0   2   0   0   1   0 ...   2   6   0
#
#    TN  TG  TR  UP  UT  WB  UN
# 0   3   2   0   4   0   2   0
# 1   3   6   0   2   0   3   0
# 2   3   6   0   2   1   0   0
# 3   6   4   0   3   0   2   0
# 4   8   4   0   3   1   0   0
#
# [5 rows x 42 columns]

# %%
def prop_forecast(df):
    m=Prophet()
    m.fit(df)
    future = m.make_future_dataframe(periods=25)
    forecast = m.predict(future)
    predictions=forecast[['ds','yhat', 'yhat_lower', 'yhat_upper']]
    return predictions

# %%
colmns=confirm_data.columns

# %%
colmns=colmns[3:41]

# %%
final_predict=pd.DataFrame(columns=["state","ds",'yhat', 'yhat_lower', 'yhat_upper'])

for i in colmns:
    df3=confirm_data[["Date",i]]
    df3=df3.rename(columns={"Date":"ds",i:"y"})
    predict1=prop_forecast(df3)
    predict1["state"]=i
    cols=["state","ds",'yhat', 'yhat_lower', 'yhat_upper']
    predict1=predict1[cols]
    final_predict=final_predict.append(predict1)
    
cols=["state","Date","cases","cases_lower","cases_upper"]
final_predict=final_predict.rename(columns={"state":"State","ds":"Date","yhat":"Cases","yhat_lower":"Cases_lower","yhat_upper":"Cases_upper"})
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# ...

# %%
final_predict.to_csv("pred_30_july_propfet.csv")
